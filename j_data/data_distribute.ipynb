# %%
# Turn of warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=UserWarning)

# %%
import os
import numpy as np
import pandas as pd
import glob
import xarray as xr
import matplotlib.pyplot as plt
import satpy

# %%
from satpy.utils import check_satpy
check_satpy(readers=['seviri_l1b_hrit'],
            writers=['geotiff', 'cf', 'simple_image'],
            extras=['cartopy', 'geoviews'] )
# Out:
# Readers
# =======
# seviri_l1b_hrit:  ok
#
# Writers
# =======
# cf:  ok
# geotiff:  ok
# simple_image:  ok
#
# Extras
# ======
# cartopy:  ok
# geoviews:  ok

# %%
## Define parameters
os.environ['XRIT_DECOMPRESS_PATH'] = '/opt/conda/pkgs/public-decomp-wt-2.8.1-h3fd9d12_1/bin/xRITDecompress'

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 9

# %%
## Define the path to the data
channel_folders =  ['IR_087___', 'VIS008___', '_________', 'WV_073___', 'IR_016___', 'VIS006___', 'HRV______', 'IR_120___', 'IR_097___', 'IR_108___', 'IR_039___', 'IR_134___', 'WV_062___']

# %%
data_folder = r"/media/knn/New Volume/Test_Data/IODC/202308140600"

# %%
date_flag  = "202308140600"
filenames = []

# %%
## Search for the files in the folder

# %%
for f_ in channel_folders:
    for row in glob.glob1(os.path.join(data_folder, f_), f'H-000-MSG2*{date_flag}*'):
        print(row)
        filenames.append(os.path.join(data_folder, f_, row))
# Out:
# H-000-MSG2__-MSG2_IODC___-IR_087___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_087___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS008___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-_________-EPI______-202308140600-__
# H-000-MSG2__-MSG2_IODC___-_________-PRO______-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_073___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_016___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-VIS006___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_120___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_097___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_108___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_039___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-IR_134___-000008___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000001___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000002___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000003___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000004___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000005___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000006___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000007___-202308140600-__
# H-000-MSG2__-MSG2_IODC___-WV_062___-000008___-202308140600-__

# %%
filenames
# Out:
# ['/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_087___/H-000-MSG2__-MSG2_IODC___-IR_087___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS008___/H-000-MSG2__-MSG2_IODC___-VIS008___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/_________/H-000-MSG2__-MSG2_IODC___-_________-EPI______-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/_________/H-000-MSG2__-MSG2_IODC___-_________-PRO______-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_073___/H-000-MSG2__-MSG2_IODC___-WV_073___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_016___/H-000-MSG2__-MSG2_IODC___-IR_016___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/VIS006___/H-000-MSG2__-MSG2_IODC___-VIS006___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_120___/H-000-MSG2__-MSG2_IODC___-IR_120___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_097___/H-000-MSG2__-MSG2_IODC___-IR_097___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_108___/H-000-MSG2__-MSG2_IODC___-IR_108___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_039___/H-000-MSG2__-MSG2_IODC___-IR_039___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/IR_134___/H-000-MSG2__-MSG2_IODC___-IR_134___-000008___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000001___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000002___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000003___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000004___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000005___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000006___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000007___-202308140600-__',
#  '/media/knn/New Volume/Test_Data/IODC/202308140600/WV_062___/H-000-MSG2__-MSG2_IODC___-WV_062___-000008___-202308140600-__']

# %%
## Create a scene for the data

# %%
scn = satpy.Scene(reader='seviri_l1b_hrit', filenames=filenames)

# %%
## seviri data chanells
seviri_data_names = ['HRV',
                     'IR_016',
                     'IR_039',
                     'IR_087',
                     'IR_097',
                     'IR_108',
                     'IR_120',
                     'IR_134',
                     'VIS006',
                     'VIS008',
                     'WV_062',
                     'WV_073']

# %%
## load the scene
scn.load(seviri_data_names)
# Out:
# Required file type '['HRIT_HRV', 'HRIT_HRV_C']' not found or loaded for 'HRV'
# The following datasets were not created and may require resampling to be generated: DataID(name='HRV', wavelength=WavelengthRange(min=0.5, central=0.7, max=0.9, unit='µm'), resolution=1000.134348869, calibration=<calibration.reflectance>, modifiers=())

# %%
scn.available_dataset_names()
# Out:
# ['IR_016',
#  'IR_039',
#  'IR_087',
#  'IR_097',
#  'IR_108',
#  'IR_120',
#  'IR_134',
#  'VIS006',
#  'VIS008',
#  'WV_062',
#  'WV_073']

# %%
scn.load(['VIS006'])

# %%
plt.figure()
scn['VIS006'].plot.imshow(cmap='viridis')

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(scn['VIS006'])
plt.colorbar()

# %%
scn['VIS006'].attrs['area']
plt.figure()

# %%
 # create a new figure
scn['HRV'][8500:9500:4, 2500:3500:4].plot.imshow()
scn['HRV'].sel(x=slice(3070000, 2070000), y=slice(2900000, 3900000))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/satpy/dataset/data_dict.py in __getitem__(self, item)
#     168             # short circuit - try to get the object without more work
# --> 169             return super(DatasetDict, self).__getitem__(item)
#     170         except KeyError:
#
# KeyError: 'HRV'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_269002/3003711808.py in <module>
#       1 # create a new figure
# ----> 2 scn['HRV'][8500:9500:4, 2500:3500:4].plot.imshow()
#       3 scn['HRV'].sel(x=slice(3070000, 2070000), y=slice(2900000, 3900000))
#
# ~/.local/lib/python3.10/site-packages/satpy/scene.py in __getitem__(self, key)
#     823         if isinstance(key, tuple):
#     824             return self.slice(key)
# --> 825         return self._datasets[key]
#     826
#     827     def __setitem__(self, key, value):
#
# ~/.local/lib/python3.10/site-packages/satpy/dataset/data_dict.py in __getitem__(self, item)
#     169             return super(DatasetDict, self).__getitem__(item)
#     170         except KeyError:
# --> 171             key = self.get_key(item)
#     172             return super(DatasetDict, self).__getitem__(key)
#     173
#
# ~/.local/lib/python3.10/site-packages/satpy/dataset/data_dict.py in get_key(self, match_key, num_results, best, **dfilter)
#     156
#     157         """
# --> 158         return get_key(match_key, self.keys(), num_results=num_results,
#     159                        best=best, **dfilter)
#     160
#
# ~/.local/lib/python3.10/site-packages/satpy/dataset/data_dict.py in get_key(key, key_container, num_results, best, query, **kwargs)
#     105     res = key.filter_dataids(key_container)
#     106     if not res:
# --> 107         raise KeyError("No dataset matching '{}' found".format(str(key)))
#     108
#     109     if best:
#
# KeyError: "No dataset matching 'DataQuery(name='HRV')' found"

# %%
scn['VIS006'].attrs['wavelength']  # in µm
# Out:
# WavelengthRange(min=0.56, central=0.635, max=0.71, unit='µm')

# %%
scn['VIS006'].attrs
scn[0.7].attrs['name']
# Out:
# 'VIS006'

# %%
nc_filename_hrv = 'seviri_test_hrv.nc'

# %%
lons, lats = scn['VIS006'].attrs['area'].get_lonlats()

# %%
from dask.diagnostics import ProgressBar
with ProgressBar():
    scn.save_datasets(tiled=True, copy_src_overviews=True)
# Out:
# [########################################] | 100% Completed | 3.84 sms

# %%
# !ls
# Out:
# data_distribute.ipynb	    IR_108_20230814_060000.tif
# docker-compose-kafka.yml    IR_120_20230814_060000.png
# docker-compose.yml	    IR_120_20230814_060000.tif
# ftp			    IR_134_20230814_060000.png
# ftp_checker.py		    IR_134_20230814_060000.tif
# geoserver		    main.py
# HRV_20230814_060000.png     requirements.txt
# IR_016_20230814_060000.png  VIS006_20230814_060000.png
# IR_016_20230814_060000.tif  VIS006_20230814_060000.tif
# IR_039_20230814_060000.png  VIS008_20230814_060000.png
# IR_039_20230814_060000.tif  VIS008_20230814_060000.tif
# IR_087_20230814_060000.png  WV_062_20230814_060000.png
# IR_087_20230814_060000.tif  WV_062_20230814_060000.tif
# IR_097_20230814_060000.png  WV_073_20230814_060000.png
# IR_097_20230814_060000.tif  WV_073_20230814_060000.tif
# IR_108_20230814_060000.png

# %%
with ProgressBar():
    scn.save_datasets(writer='simple_image')
# Out:
# [########################################] | 100% Completed | 6.30 sms

# %% [markdown]
# ### RESAMPLE
# Convert the data to the projected surface

# %%
new_scn = scn.resample(resampler='native')
new_scn['VIS006'] ## 11136 x 11136 
# scn['VIS006']  ## 3712 x 3712 
# plt.figure()
# plt.imshow(new_scn['VIS006'])
# plt.colorbar()
# Out:
# <xarray.DataArray '_repeat_by_factor-2b9c57ac830a173d9fe8a3c71132bcd0' (
#                                                                         y: 11136,
#                                                                         x: 11136)>
# dask.array<_repeat_by_factor, shape=(11136, 11136), dtype=float32, chunksize=(1392, 11136), chunktype=numpy.ndarray>
# Coordinates:
#     crs      object PROJCRS["unknown",BASEGEOGCRS["unknown",DATUM["unknown",E...
#   * y        (y) float64 -5.566e+06 -5.565e+06 -5.564e+06 ... 5.57e+06 5.571e+06
#   * x        (x) float64 5.566e+06 5.565e+06 5.564e+06 ... -5.57e+06 -5.571e+06
# Attributes: (12/22)
#     orbital_parameters:                     {'projection_longitude': 45.5, 'p...
#     time_parameters:                        {'nominal_start_time': datetime.d...
#     nominal_start_time:                     (datetime.datetime(2023, 8, 14, 6...
#     georef_offset_corrected:                True
#     sensor:                                 seviri
#     standard_name:                          toa_bidirectional_reflectance
#     ...                                     ...
#     name:                                   VIS006
#     resolution:                             3000.403165817
#     calibration:                            reflectance
#     modifiers:                              ()
#     _satpy_id:                              DataID(name='VIS006', wavelength=...
#     ancillary_variables:                    []

# %%
from pyresample import create_area_def
# create_area_def?

# %%
my_area = create_area_def('my_area', {'proj': 'longlat', 'datum': 'WGS84'},
                           area_extent=[22, 30, 45, 45],
                           resolution=0.01,
                           units='degrees',
                           description='Global 0.01x0.01 degree lat-lon grid')

# %%
new_scn = scn.resample(my_area)
new_scn['VIS006']
# Out:
# <xarray.DataArray 'my_index-a1438ba0a6f174a8d1da6881985f4ec5' (y: 1500, x: 2300)>
# dask.array<my_index, shape=(1500, 2300), dtype=float32, chunksize=(1500, 2300), chunktype=numpy.ndarray>
# Coordinates:
#     crs      object GEOGCRS["unknown",DATUM["World Geodetic System 1984",ELLI...
#   * y        (y) float64 44.99 44.98 44.97 44.96 ... 30.03 30.02 30.01 30.0
#   * x        (x) float64 22.0 22.02 22.02 22.04 22.04 ... 44.97 44.97 44.98 45.0
# Attributes: (12/22)
#     orbital_parameters:                     {'projection_longitude': 45.5, 'p...
#     time_parameters:                        {'nominal_start_time': datetime.d...
#     nominal_start_time:                     (datetime.datetime(2023, 8, 14, 6...
#     georef_offset_corrected:                True
#     sensor:                                 seviri
#     standard_name:                          toa_bidirectional_reflectance
#     ...                                     ...
#     name:                                   VIS006
#     resolution:                             3000.403165817
#     calibration:                            reflectance
#     modifiers:                              ()
#     _satpy_id:                              DataID(name='VIS006', wavelength=...
#     ancillary_variables:                    []

# %%
from dask.diagnostics import ProgressBar
with ProgressBar():
    new_scn.save_datasets(tiled=True, copy_src_overviews=True)
# Out:
# [########################################] | 100% Completed | 1.65 sms

# %%
my_area.pixel_size_x, my_area.pixel_size_y
# Out:
# (0.01, 0.01)

# %%
plt.figure()
new_scn['VIS006'].plot.imshow(vmin=0, vmax=100)

# %% [markdown]
# ### Display over Map

# %%
from ipyleaflet import Map, basemaps, LayersControl, WidgetControl
import rioxarray
from ipyleaflet import Map, basemaps, projections

# %%
import xarray_leaflet 
da = rioxarray.open_rasterio('HRV_20230814_060000.tif', masked=True)

da = da.sel(band=1)
da.name = 'HRV'

# %%
import rioxarray

# %%
m = Map(center=[40,40], zoom=1 , basemap=basemaps.Esri.NatGeoWorldMap,crs=projections.EPSG4326, interpolation='nearest')
m
l = da.leaflet.plot(m, colormap=plt.cm.terrain)
# m
# l.interact(opacity=(0., 1.))
# Out:
# Url()

# %%
# Out:
# Map(center=[40, 40], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# ### Export to netcdf

# %%
## save the data to netcdf for visible 
scn.save_datasets(writer='cf', datasets= [row for row in seviri_data_names if row is not 'HRV'], filename=nc_filename_vis)

print('done')

# %%
## save the data to netcdf for hrv 
scn.save_datasets(writer='cf', datasets=['HRV'], filename=nc_filename_hrv)
print('done')

# %%
## define a function to get metadata of netcdf
import netCDF4 as nc

def display_netcdf_info(file_path):
    # Open the NetCDF file
    with nc.Dataset(file_path) as ds:
        # Display general attributes
        print("Global Attributes:")
        for name in ds.ncattrs():
            print(f"{name}: {ds.getncattr(name)}")
        print("\n")

        # Display dimensions
        print("Dimensions:")
        for name, dim in ds.dimensions.items():
            print(f"{name}: {len(dim)}")
        print("\n")

        # Display variables and their attributes
        print("Variables:")
        for name, var in ds.variables.items():
            print(f"{name}:")
            for attr_name in var.ncattrs():
                print(f"    {attr_name}: {var.getncattr(attr_name)}")
        print("\n")
import xarray as xr

def display_netcdf_info_xarray(file_path):
    # Open the NetCDF file with xarray
    ds = xr.open_dataset(file_path)
    
    # Display dataset
    print(ds)
    
    # Close the dataset
    ds.close()

# %%
## Display netcdf

# %%
display_netcdf_info_xarray(nc_filename_hrv)

# %%
## Display visible data metadata
display_netcdf_info(nc_filename_vis)
